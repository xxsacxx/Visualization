# %%
import pandas as pd
from plotnine import *
import numpy as np

# %%
df=pd.read_csv("pictures.csv")

# %%
df.head()
# Out:
#                  name  year  nominations  rating  duration     genre1 genre2  \
# 0             Birdman  2014            9     7.8       119     Comedy  Drama
# 1    12 Years a Slave  2013            9     8.1       134  Biography  Drama
# 2                Argo  2012            7     7.8       120  Biography  Drama
# 3          The Artist  2011           10     8.0       100     Comedy  Drama
# 4   The King's Speech  2010           12     8.0       118  Biography  Drama
#
#     release  metacritic                                           synopsis  \
# 0  November        88.0  Illustrated upon the progress of his latest Br...
# 1  November        97.0  In the antebellum United States Solomon Northu...
# 2   October        86.0  Acting under the cover of a Hollywood producer...
# 3   October        89.0  A silent movie star meets a young dancer but t...
# 4  December        88.0  The story of King George VI of the United King...
#
#   Unnamed: 10
# 0         NaN
# 1         NaN
# ...

# %%
print(type(df.nominations[0]))
print(type(df.rating[0]))
print(type(df.duration[0]))
# Out:
# <type 'numpy.int64'>
# <type 'numpy.float64'>
# <type 'numpy.int64'>

# %%
nomination=df.nominations.astype(int)

# %%
(ggplot(df, 
        aes('rating','metacritic')) 
        + geom_point()
        + theme_bw())
# Out:
# /home/sachin/miniconda3/envs/face_reco/lib/python2.7/site-packages/plotnine/layer.py:452: UserWarning: geom_point : Removed 44 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# <ggplot: (8761405774833)>

# %%
(ggplot(df, 
            aes('rating','metacritic', color='factor(genre1)'))
            + geom_point()
            + theme_bw())
# Out:
# /home/sachin/miniconda3/envs/face_reco/lib/python2.7/site-packages/plotnine/layer.py:452: UserWarning: geom_point : Removed 44 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# <ggplot: (8761405759633)>

# %%
(ggplot(df, 
        aes('rating','metacritic', color='factor(genre1)', size='duration'))
        + geom_point() 
        + theme_bw())
# Out:
# /home/sachin/miniconda3/envs/face_reco/lib/python2.7/site-packages/plotnine/layer.py:452: UserWarning: geom_point : Removed 44 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# <ggplot: (8761403543209)>

# %%
(ggplot(df, 
        aes('rating','metacritic', color='factor(genre1)'))
        + geom_point() 
        +  facet_wrap('~release')
        + theme_bw())
# Out:
# /home/sachin/miniconda3/envs/face_reco/lib/python2.7/site-packages/numpy/lib/arraysetops.py:200: FutureWarning: numpy not_equal will not check object identity in the future. The comparison did not return the same result as suggested by the identity (`is`)) and will change.
#   flag = np.concatenate(([True], aux[1:] != aux[:-1]))
# /home/sachin/miniconda3/envs/face_reco/lib/python2.7/site-packages/plotnine/layer.py:452: UserWarning: geom_point : Removed 44 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# <ggplot: (8761403572597)>

# %%
(ggplot(df, 
        aes('rating','metacritic', color='factor(genre1)',size='duration'))
        + geom_point() 
        +  facet_wrap('~release')
        + theme_bw())
# Out:
# /home/sachin/miniconda3/envs/face_reco/lib/python2.7/site-packages/plotnine/layer.py:452: UserWarning: geom_point : Removed 44 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# <ggplot: (8761403356565)>

# %%
(ggplot(df, 
        aes('rating','metacritic', color='factor(genre1)'))
        + geom_point() 
        + stat_smooth(method='lm') 
        + theme_bw())
# Out:
# /home/sachin/miniconda3/envs/face_reco/lib/python2.7/site-packages/plotnine/layer.py:452: UserWarning: geom_point : Removed 44 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# <ggplot: (8761402887285)>
